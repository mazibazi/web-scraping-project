# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # insert Site Address

# %%
page = requests.get("https://divar.ir/s/tehran")
page
# Out:
# <Response [200]>

# %% [markdown]
# [In here We can Status Code Response](https://www.w3.org/Protocols/rfc2616/rfc2616-sec10.html)

# %%
soup = BeautifulSoup(page.text, "html.parser")
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html dir="rtl" lang="fa-IR">\n <head>\n  <title data-react-helmet="true">\n   دیوار تهران: مرجع انواع نیازمندی و آگهی\u200cهای نو و دست دو در شهر تهران\n  </title>\n  <meta content="width=992, initial-scale=1" data-react-helmet="true" name="viewport"/>\n  <meta content="در دیوار تهران هم رایگان آگهی ثبت کنید و هم میلیون\u200cها آگهی و نیازمندی را در شهر تهران مشاهده کنید" data-react-helmet="true" name="description"/>\n  <meta content="summary" data-react-helmet="true" name="twitter:card"/>\n  <meta content="@divar_official" data-react-helmet="true" name="twitter:site"/>\n  <meta content="https://divar.ir/s/tehran" data-react-helmet="true" name="twitter:url"/>\n  <meta content="دیوار تهران: مرجع انواع نیازمندی و آگهی\u200cهای نو و دست دو در شهر تهران" data-react-helmet="true" name="twitter:title"/>\n  <meta content="در دیوار تهران هم رایگان آگهی ثبت کنید و هم میلیون\u200cها آگهی و نیازمندی را در شهر تهران مشاهده کنید" data-react-helmet="true" name="twitter:description"/>\n  <meta content="https://s100.divarcdn.com/static/thewall-assets/android-chrome-512x512.png" data-react-helmet="true" name="twitter:image"/>\n  <meta content="دیوار" data-react-helmet="true" name="twitter:creator"/>\n  <meta content="دیوار" data-react-helmet="true" property="og:site_name"/>\n  <meta content="product" data-react-helmet="true" property="og:type"/>\n  <meta content="https://divar.ir/s/tehran" data-react-helmet="true" property="og:url"/>\n  <meta content="دیوار تهران: مرجع انواع نیازمندی و آگهی\u200cهای نو و دست دو در شهر تهران" data-react-helmet="true" property="og:title"/>\n  <meta content="در دیوار تهران هم رایگان آگهی ثبت کنید و هم میلیون\u200cها آگهی و نیازمندی را در شهر تهران مشاهده کنید" data-react-helmet="true" property="og:description"/>\n  <meta content="https://s100.divarcdn.com/static/thewall-assets/android-chrome-512x512.png" data-react-helmet="true" property="og:image"/>\n  <meta content="fa_IR" data-react-helmet="true" property="og:locale"/>\n  <meta content="INDEX,FOLLOW" data-react-helmet="true" name="robots"/>\n  <meta content="app-id=ir.divar" data-react-helmet="true" name="google-play-app"/>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <link as="script" data-chunk="main" href="https://s100.divarcdn.com/statics/2021/10/runtime.0599f587.desktop.js" rel="modulepreload"/>\n  <link as="script" data-chunk="main" href="https://s100.divarcdn.com/statics/2021/10/polyfills.2b1b493f.desktop.js" rel="modulepreload"/>\n  <link as="script" data-chunk="main" href="https://s100.divarcdn.com/statics/2021/10/vendors.ff418d39.desktop.js" rel="modulepreload"/>\n  <link as="script" data-chunk="main" href="https://s100.divarcdn.com/statics/2021/10/khesht.68af7aab.desktop.js" rel="modulepreload"/>\n  <link as="script" data-chunk="main" href="https://s100.divarcdn.com/statics/2021/10/main.018416aa.desktop.js" rel="modulepreload"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <link href="https://s100.divarcdn.com/static/thewall-assets/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>\n  <link href="https://s100.divarcdn.com/static/thewall-assets/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="https://s100.divarcdn.com/static/thewall-assets/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>\n  <link color="#a62626" href="https://s100.divarcdn.com/static/thewall-assets/safari-pinned-tab.svg" rel="mask-icon"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <link href="https://plus.google.com/+DivarIr" rel="publisher"/>\n  <link data-react-helmet="true" href="https://s100.divarcdn.com/static/thewall-assets/android-chrome-512x512.png" rel="apple-touch-icon">\n   <link data-react-helmet="true" href="https://s100.divarcdn.com/static/thewall-assets/android-chrome-512x512.png" rel="android-touch-icon">\n    <link as="font" crossorigin="anonymous" data-react-helmet=" ...

# %% [markdown]
# # For knowing html

# %% [markdown]
# We search for tage

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34916/3962507836.py in <module>
#       1 title = []
# ----> 2 for header in bsobj.findAll('h2',{'class':'title'}):
#       3   title.append(header.text.strip())
#
# NameError: name 'bsobj' is not defined

# %% [markdown]
# We are looking for id

# %%
products = soup.find_all("div", class_="kt-post-card__title")
products
# Out:
# [<div class="kt-post-card__title">اتو دلونگی</div>,
#  <div class="kt-post-card__title">۶ عدد کیک خوری طلایی آنتیک</div>,
#  <div class="kt-post-card__title">سکه یادبود</div>,
#  <div class="kt-post-card__title">کاج مطبق</div>,
#  <div class="kt-post-card__title">تخت گهواره ای بچه</div>,
#  <div class="kt-post-card__title">پژو 405 SLX بنزینی، مدل ۱۳۸۹</div>,
#  <div class="kt-post-card__title">برنج هندی باز</div>,
#  <div class="kt-post-card__title">93 متر فردوس شرق.نوساز کلید نخورده</div>,
#  <div class="kt-post-card__title">مولینکس اصل هست وکم کارکرده</div>,
#  <div class="kt-post-card__title">کابینت mdf</div>,
#  <div class="kt-post-card__title">مبل سلطنتی</div>,
#  <div class="kt-post-card__title">بوت اسنوبرد nitro</div>,
#  <div class="kt-post-card__title">صندلی انتظار شطرنجی</div>,
#  <div class="kt-post-card__title">صندلی انتظار اداری</div>,
#  <div class="kt-post-card__title">صندلی اموزشی مدل ام پی</div>,
#  <div class="kt-post-card__title">صندلی گردان صدفی دسته دار زرد</div>,
#  <div class="kt-post-card__title">صندلی انتظار مقاوم</div>,
#  <div class="kt-post-card__title">صندلی نماز بدون سبد</div>,
#  <div class="kt-post-card__title">صندلی اپن پایه بلند مدل ام پی</div>,
#  <div class="kt-post-card__title">صندلی گردان صدفی بدون دسته</div>,
#  <div class="kt-post-card__title">صندلی مدیریت لاندا</div>,
#  <div class="kt-post-card__title">صندلی انتظار آرام</div>,
#  <div class="kt-post-card__title">دوچرخه سایز 26</div>,
#  <div class="kt-post-card__title">کاپشن پسرانه .مردانه ۱۳تا ۱۵سال</div>]

# %%
listProducts = []
for item in products:
    listProducts.append(item.text)
# Out:
# ['اتو دلونگی',
#  '۶ عدد کیک خوری طلایی آنتیک',
#  'سکه یادبود',
#  'کاج مطبق',
#  'تخت گهواره ای بچه',
#  'پژو 405 SLX بنزینی، مدل ۱۳۸۹',
#  'برنج هندی باز',
#  '93 متر فردوس شرق.نوساز کلید نخورده',
#  'مولینکس اصل هست وکم کارکرده',
#  'کابینت mdf',
#  'مبل سلطنتی',
#  'بوت اسنوبرد nitro',
#  'صندلی انتظار شطرنجی',
#  'صندلی انتظار اداری',
#  'صندلی اموزشی مدل ام پی',
#  'صندلی گردان صدفی دسته دار زرد',
#  'صندلی انتظار مقاوم',
#  'صندلی نماز بدون سبد',
#  'صندلی اپن پایه بلند مدل ام پی',
#  'صندلی گردان صدفی بدون دسته',
#  'صندلی مدیریت لاندا',
#  'صندلی انتظار آرام',
#  'دوچرخه سایز 26',
#  'کاپشن پسرانه .مردانه ۱۳تا ۱۵سال']

# %%
price = soup.find_all("div", class_ = "kt-post-card__description")

# %%
agreementPrice = '\u062A\u0648\u0627\u0641\u0642\u06CC'
print(agreementPrice)
# Out:
# توافقی

# %%
listPrice = []
for item in price:
    listPrice.append(item.text)
# Out:
# ['۵۰۰,۰۰۰ تومان',
#  '۳۵۰,۰۰۰ تومان',
#  '۱۸,۰۰۰,۰۰۰ تومان',
#  '۲۵۰,۰۰۰ تومان',
#  '۲۰۰,۰۰۰ تومان',
#  '۱۶۰ کیلومتر\n۱۱۶,۰۰۰,۰۰۰ تومان',
#  '۱۷۰,۰۰۰ تومان',
#  '۳,۹۰۰,۰۰۰,۰۰۰ تومان',
#  '۱,۰۰۰,۰۰۰ تومان',
#  'توافقی',
#  '۳,۸۰۰,۰۰۰ تومان',
#  'توافقی',
#  '۳۵۰,۰۰۰ تومان',
#  '۲۰۰,۰۰۰ تومان',
#  '۲۶۰,۰۰۰ تومان',
#  '۴۷۰,۰۰۰ تومان',
#  '۲۰۰,۰۰۰ تومان',
#  '۴۰۰,۰۰۰ تومان',
#  '۲۸۰,۰۰۰ تومان',
#  '۴۳۰,۰۰۰ تومان',
#  '۸۳۰,۰۰۰ تومان',
#  '۳۶۰,۰۰۰ تومان',
#  '۳,۰۰۰,۰۰۰ تومان',
#  '۴۰۰,۰۰۰ تومان']

# %%
counterIndex = 0
targetCounter = []
for el in listPrice:
    if el == agreementPrice:
        targetCounter.append(counterIndex)
    counterIndex += 1
# Out:
# [9, 11]

# %%
for el in targetCounter:
    print(listProducts[el], listPrice[el])
# Out:
# کابینت mdf توافقی
# بوت اسنوبرد nitro توافقی
